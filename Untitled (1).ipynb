# %%
import pandas as pd

# %%
data = pd.read_csv('customer_churn_dataset.csv')
data.head()
# Out:
#    customer_id  tenure  monthly_charges  total_charges        contract  \
# 0            1      52            54.20        2818.40  Month-to-month
# 1            2      15            35.28         529.20  Month-to-month
# 2            3      72            78.24        5633.28  Month-to-month
# 3            4      61            80.24        4894.64        One year
# 4            5      21            39.38         826.98  Month-to-month
#
#   payment_method internet_service tech_support online_security  support_calls  \
# 0         Credit              DSL           No             Yes              1
# 1          Debit              DSL           No              No              2
# 2          Debit              DSL           No              No              0
# 3           Cash            Fiber          Yes             Yes              0
# 4            UPI            Fiber           No              No              4
#
#   churn
# 0    No
# 1    No
# 2    No
# 3    No
# 4   Yes

# %%
data.isnull().sum()
# Out:
# customer_id         0
# tenure              0
# monthly_charges     0
# total_charges       0
# contract            0
# payment_method      0
# internet_service    0
# tech_support        0
# online_security     0
# support_calls       0
# churn               0
# dtype: int64

# %%
data['internet_service'].value_counts()
# Out:
# internet_service
# Fiber      10064
# DSL         7923
# unknown     2013
# Name: count, dtype: int64

# %%
data['internet_service'].fillna('unknown',inplace = True)
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_15720\883606526.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['internet_service'].fillna('unknown',inplace = True)

# %%
data.describe()
# Out:
#         customer_id        tenure  monthly_charges  total_charges  \
# count  20000.000000  20000.000000     20000.000000   20000.000000
# mean   10000.500000     36.467450        70.010531    2543.979209
# std     5773.647028     20.773984        28.890239    1882.949804
# min        1.000000      1.000000        20.000000      20.230000
# 25%     5000.750000     18.000000        45.210000    1045.837500
# 50%    10000.500000     36.000000        70.090000    2096.495000
# 75%    15000.250000     54.000000        95.072500    3690.337500
# max    20000.000000     72.000000       120.000000    8629.920000
#
#        support_calls
# count    20000.00000
# mean         1.51255
# std          1.23524
# min          0.00000
# 25%          1.00000
# 50%          1.00000
# 75%          2.00000
# max          8.00000

# %%
data.dtypes
# Out:
# customer_id                   int64
# tenure                        int64
# monthly_charges             float64
# total_charges               float64
# support_calls                 int64
# churn                         int64
# contract_One year              bool
# contract_Two year              bool
# payment_method_Credit          bool
# payment_method_Debit           bool
# payment_method_UPI             bool
# internet_service_Fiber         bool
# internet_service_unknown       bool
# tech_support_Yes               bool
# online_security_Yes            bool
# dtype: object

# %%
data['churn'] = data['churn'].map({'Yes': 1, 'No': 0})

# %%
data = pd.get_dummies(data, drop_first = True)

# %%
data.head()
# Out:
#    customer_id  tenure  monthly_charges  total_charges  support_calls  churn  \
# 0            1      52            54.20        2818.40              1      0
# 1            2      15            35.28         529.20              2      0
# 2            3      72            78.24        5633.28              0      0
# 3            4      61            80.24        4894.64              0      0
# 4            5      21            39.38         826.98              4      1
#
#    chrn  contract_One year  contract_Two year  payment_method_Credit  \
# 0     0              False              False                   True
# 1     0              False              False                  False
# 2     0              False              False                  False
# 3     0               True              False                  False
# 4     1              False              False                  False
#
#    payment_method_Debit  payment_method_UPI  internet_service_Fiber  \
# ...

# %%
data.drop(columns = 'chrn',inplace = True)

# %%
from sklearn.model_selection import train_test_split

# %%
x = data.drop(columns = 'churn', axis = 1)
y = data['churn']

x_train,x_test,y_train,y_test = train_test_split(x,y, random_state = 42, test_size = 0.2)

# %%
from sklearn.linear_model import LogisticRegression

model = LogisticRegression(max_iter = 1000)
model.fit(x_train,y_train)
# Out:
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression(max_iter=1000)

# %%
y = model.predict(x_test)
y
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
from sklearn.metrics import accuracy_score
accuracy = accuracy_score(y_test,y)

# %%
print(f' In this model,the acurracy of the y_test to the predicted value is {accuracy}' )
# Out:
#  In this model,the acurracy of the y_test to the predicted value is 0.78975

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,y))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.91      0.85      2645
#            1       0.76      0.56      0.64      1355
#
#     accuracy                           0.79      4000
#    macro avg       0.78      0.73      0.75      4000
# weighted avg       0.79      0.79      0.78      4000

# %%
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

cm = confusion_matrix(y_test, y)

sns.heatmap(cm, annot=True, fmt='d')
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.show()

# %%
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier()
rf.fit(x_train, y_train)

pred_rf = rf.predict(x_test)

from sklearn.metrics import classification_report
print(classification_report(y_test, pred_rf))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.94      0.90      2645
#            1       0.86      0.68      0.76      1355
#
#     accuracy                           0.86      4000
#    macro avg       0.86      0.81      0.83      4000
# weighted avg       0.86      0.86      0.85      4000

# %%
importance = rf.feature_importances_
features = x.columns

feat_imp = pd.Series(importance, index=features).sort_values(ascending=False)
print(feat_imp.head(10))
# Out:
# monthly_charges           0.231473
# total_charges             0.148494
# customer_id               0.132098
# tenure                    0.129102
# support_calls             0.107528
# tech_support_Yes          0.075811
# contract_One year         0.060646
# contract_Two year         0.044172
# online_security_Yes       0.015718
# internet_service_Fiber    0.014730
# dtype: float64

# %%
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier(class_weight='balanced')
rf.fit(x_train, y_train)
# Out:
# RandomForestClassifier(class_weight='balanced')

# %%
pred_rf = rf.predict(x_test)

from sklearn.metrics import classification_report
print(classification_report(y_test, pred_rf))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.94      0.90      2645
#            1       0.86      0.68      0.76      1355
#
#     accuracy                           0.86      4000
#    macro avg       0.86      0.81      0.83      4000
# weighted avg       0.86      0.86      0.85      4000
